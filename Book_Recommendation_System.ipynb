# %% [markdown]
# ## Book Recommendation System

# %% [markdown]
# #### Importing the Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #### Importing the Dataset

# %%
books_df=pd.read_csv('books.csv')
ratings_df=pd.read_csv('ratings.csv')
users_df=pd.read_csv('users.csv')
# Out:
# C:\Users\ABHIRAM NAIDU\AppData\Local\Temp\ipykernel_16836\1225184402.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df=pd.read_csv('books.csv')

# %%
print("Books Dataset:")
books_df.head()
# Out:
# Books Dataset:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
print("Shape of Books Dataset:",books_df.shape)
# Out:
# Shape of Books Dataset: (271360, 8)

# %%
print("Information About the Books Dataset:",books_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB
# Information About the Books Dataset: None

# %%
print("Missing values in Books Dataset:")
print(books_df.isnull().sum())
# Out:
# Missing values in Books Dataset:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
print("Duplicate rows in Books Dataset:", books_df.duplicated().sum())
# Out:
# Duplicate rows in Books Dataset: 0

# %%
print("Descriptive statistics of Books Dataset:")
print(books_df.describe())
# Out:
# Descriptive statistics of Books Dataset:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# ...

# %%
print("Ratings Dataset:")
print(ratings_df.head())
# Out:
# Ratings Dataset:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print("Shape of Ratings Dataset:",ratings_df.shape)
# Out:
# Shape of Ratings Dataset: (1149780, 3)

# %%
print("Information about Ratings Dataset:")
print(ratings_df.info())
# Out:
# Information about Ratings Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB
# None

# %%
print("Missing Values in Ratings Dataset:",ratings_df.isnull().sum())
# Out:
# Missing Values in Ratings Dataset: User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
print("Duplicate rows in Ratings Dataset:", ratings_df.duplicated().sum())
# Out:
# Duplicate rows in Ratings Dataset: 0

# %%
print("Descriptive statistics of Ratings Dataset:")
print(ratings_df.describe())
# Out:
# Descriptive statistics of Ratings Dataset:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
print("Users Dataset:")
print(users_df.head())
# Out:
# Users Dataset:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print("Shape of Users Dataset:", users_df.shape)
# Out:
# Shape of Users Dataset: (278858, 3)

# %%
print("Information about Users Dataset:")
print(users_df.info())
# Out:
# Information about Users Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB
# None

# %%
print("Missing values in Users Dataset:")
print(users_df.isnull().sum())
# Out:
# Missing values in Users Dataset:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
print("Duplicate rows in Users Dataset:", users_df.duplicated().sum())
# Out:
# Duplicate rows in Users Dataset: 0

# %%
print("Descriptive statistics of Users Dataset:")
print(users_df.describe())
# Out:
# Descriptive statistics of Users Dataset:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %% [markdown]
# ### Popularity Based Recommendation System

# %% [markdown]
# 1.In Popularity Based Recommendation System I will be displaying the top 50 high average rating books
# 2.I will be Considering  only the books which are rated by atleast 250 persons because books voted by lesser number of people does not affect the average rating at all.
# 3.For achieving this I will be Merging the ratings and books dataframe based on the ISBN Column

# %%
ratings_with_name=ratings_df.merge(books_df,on='ISBN') # merging the ratings and books dataframe

# %%
# Grouping the ratings_with_name dataframe by the title of the books and the number of ratings
grouped_ratings = ratings_with_name.groupby(['Book-Title']).size().reset_index(name='Number-of-Ratings')

# Displaying the grouped ratings
grouped_ratings.head()
# Out:
#                                           Book-Title  Number-of-Ratings
# 0   A Light in the Storm: The Civil War Diary of ...                  4
# 1                              Always Have Popsicles                  1
# 2               Apple Magic (The Collector's series)                  1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...                  1
# 4   Beyond IBM: Leadership Marketing and Finance ...                  1

# %%
grouped_ratings
# Out:
#                                                Book-Title  Number-of-Ratings
# 0        A Light in the Storm: The Civil War Diary of ...                  4
# 1                                   Always Have Popsicles                  1
# 2                    Apple Magic (The Collector's series)                  1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...                  1
# 4        Beyond IBM: Leadership Marketing and Finance ...                  1
# ...                                                   ...                ...
# 241066                                      Ã?Â?lpiraten.                  2
# 241067                     Ã?Â?rger mit Produkt X. Roman.                  4
# 241068                                Ã?Â?sterlich leben.                  1
# 241069                              Ã?Â?stlich der Berge.                  3
# 241070                                  Ã?Â?thique en toc                  2
#
# [241071 rows x 2 columns]

# %%
average_rating=ratings_with_name.groupby(['Book-Title'])["Book-Rating"].mean().reset_index(name="Average-Ratings") # Grouping the ratings_with_name dataframe by the title of the books and the average ratings

# %%
average_rating.head()
# Out:
#                                           Book-Title  Average-Ratings
# 0   A Light in the Storm: The Civil War Diary of ...             2.25
# 1                              Always Have Popsicles             0.00
# 2               Apple Magic (The Collector's series)             0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...             8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...             0.00

# %%
popularity_df=grouped_ratings.merge(average_rating,on="Book-Title") # Merging the grouped_ratings and average_ratings dataframe

# %%
# Selecting rows with number of ratings greater than 250
filtered_df=popularity_df[popularity_df['Number-of-Ratings']>=250]

# Sorting the filtered DataFrame in descending order of average rating
sorted_df=filtered_df.sort_values(by='Average-Ratings', ascending=False)

# Displaying the sorted DataFrame
sorted_df
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 80422        Harry Potter and the Goblet of Fire (Book 4)                387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)                278
# 80426   Harry Potter and the Order of the Phoenix (Boo...                347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)                556
# ...                                                   ...                ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))                265
# 233635                                           Whispers                286
# 143377                                  Presumed Innocent                294
# 94382                                        Isle of Dogs                288
# 234951                                        Wild Animus               2502
#
#         Average-Ratings
# ...

# %%
sorted_df.merge(books_df,on="Book-Title") # Merging the sorted_df and books_df dataframe
# Out:
#                                             Book-Title  Number-of-Ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 1    Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 2    Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 3         Harry Potter and the Goblet of Fire (Book 4)                387
# 4         Harry Potter and the Goblet of Fire (Book 4)                387
# ..                                                 ...                ...
# 735                                       Isle of Dogs                288
# 736                                       Isle of Dogs                288
# 737                                       Isle of Dogs                288
# 738                                       Isle of Dogs                288
# 739                                        Wild Animus               2502
#
#      Average-Ratings        ISBN                Book-Author  \
# ...

# %%
sorted_df.merge(books_df,on="Book-Title").drop_duplicates(subset=["Book-Title"]) # Merging the sorted_df and books_df dataframe and dropping the duplicate rows
# Out:
#                                             Book-Title  Number-of-Ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 3         Harry Potter and the Goblet of Fire (Book 4)                387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)                278
# 9    Harry Potter and the Order of the Phoenix (Boo...                347
# 13    Harry Potter and the Chamber of Secrets (Book 2)                556
# ..                                                 ...                ...
# 716       Vinegar Hill (Oprah's Book Club (Paperback))                265
# 717                                           Whispers                286
# 727                                  Presumed Innocent                294
# 733                                       Isle of Dogs                288
# 739                                        Wild Animus               2502
#
#      Average-Ratings        ISBN        Book-Author Year-Of-Publication  \
# ...

# %%
sorted_df.shape
# Out:
# (186, 3)

# %%
top_50_books = sorted_df.head(50) # Selecting the top 50 books
top_50_books
# Out:
#                                                Book-Title  Number-of-Ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)                428
# 80422        Harry Potter and the Goblet of Fire (Book 4)                387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)                278
# 80426   Harry Potter and the Order of the Phoenix (Boo...                347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)                556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...                281
# 187377  The Fellowship of the Ring (The Lord of the Ri...                368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...                575
# 211384     The Two Towers (The Lord of the Rings, Part 2)                260
# 219741                              To Kill a Mockingbird                510
# 183573                                  The Da Vinci Code                898
# ...
